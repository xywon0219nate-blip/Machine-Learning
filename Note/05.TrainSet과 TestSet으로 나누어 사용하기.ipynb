# %% [markdown]
# ##### Train Set 과 Test Set의 중요성
# - 모든 문제와 답을 알려주고 해당 범위 내에서 점수를 내면 항상 100점이 나온다.
# - 한갸의 Data Set을 Train 부분과 Test부분으로 분리
# - Train Set은 학습하고 학습한 결과 내용으로 Test Set

# %%
import pandas as pd

# %%
fruits = pd.read_csv("../Data/fruits.csv")
fruits.head()
# Out:
#    length  weight   name
# 0    25.4   242.0  apple
# 1    26.3   290.0  apple
# 2    26.5   340.0  apple
# 3    29.0   363.0  apple
# 4    29.0   430.0  apple

# %% [markdown]
# ## Train Set 과 Test Set로 분리하기

# %%
# Train Set
train_input = fruits.loc[:34,['length', 'weight']]
train_input.tail()
# Out:
#     length  weight
# 30    38.5   920.0
# 31    38.5   955.0
# 32    39.5   925.0
# 33    41.0   975.0
# 34    41.0   950.0

# %%
train_target = fruits.loc[:34,['name']]
train_target.tail()
# Out:
#      name
# 30  apple
# 31  apple
# 32  apple
# 33  apple
# 34  apple

# %%
# Test Set
test_input = fruits.loc[34:,['length', 'weight']]
test_input.tail()
# Out:
#     length  weight
# 44    12.2    12.2
# 45    12.4    13.4
# 46    13.0    12.2
# 47    14.3    19.7
# 48    15.0    19.9

# %%
test_target = fruits.loc[34:,['name']]
test_target.tail()
# Out:
#      name
# 44  berry
# 45  berry
# 46  berry
# 47  berry
# 48  berry

# %% [markdown]
# #### kNN을 이용한 분류

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Model
kn = KNeighborsClassifier()

# %%
# 학습시키기
kn.fit(train_input,train_target)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neighbors/_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# 평가하기
print(kn.score(train_input,train_target))
print(kn.score(test_input,test_target))
# Out:
# 1.0
# 0.06666666666666667

# %% [markdown]
#    > 샘플링 편향이 발생하였다.

# %% [markdown]
# ----
# ## Numpy를 이용하여 샘플링 편향을 제거하기

# %%
import numpy as np

# %%
np.random.seed(42) # random sample을 하나로 정의하여 다른 모델에서도 
index = np.arange(49)
np.random.shuffle(index)
print(index)
# Out:
# [13 45 47 44 17 27 26 25 31 19 12  4 34  8  3  6 40 41 46 15  9 16 24 33
#  30  0 43 32  5 29 11 36  1 21  2 37 35 23 39 10 22 18 48 20  7 42 14 28
#  38]

# %%
# train data 구성
train_input = fruits.loc[index[:35],['length', 'weight']]
train_input.head()
# Out:
#     length  weight
# 13    32.0   340.0
# 45    12.4    13.4
# 47    14.3    19.7
# 44    12.2    12.2
# 17    33.0   700.0

# %%
# test data 구성
test_input = fruits.loc[index[35:],['length', 'weight']]
test_input.head()
# Out:
#     length  weight
# 37    10.6     7.0
# 35     9.8     6.7
# 23    35.0   680.0
# 39    11.2     9.8
# 10    31.0   475.0

# %%
train_target = fruits.loc[index[:35], ['name']]
test_target = fruits.loc[index[35:], ['name']]

# %% [markdown]
# ### Data의 분포를 산포도로 확인하기

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(
    train_input['length'],
    train_input['weight']
)
plt.scatter(
    test_input['length'],
    test_input['weight']
)

# %%
# knn으로 학습
kn.fit(train_input, train_target)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neighbors/_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# knn으로 정확도 출력 (train, test)
print(kn.score(train_input,train_target))
print(kn.score(test_input,test_target))
# Out:
# 1.0
# 1.0

# %% [markdown]
# ## sklearn으로 Train Set과 Test Set 나누기

# %%
from sklearn.model_selection import train_test_split

# %%
# Feature와 Target으로 분리
fruits_data = fruits[['length', 'weight']]
fruits_target = fruits['name']
fruits_data.head()
# Out:
#    length  weight
# 0    25.4   242.0
# 1    26.3   290.0
# 2    26.5   340.0
# 3    29.0   363.0
# 4    29.0   430.0

# %%
train_input, test_input, train_target, test_target = \
train_test_split(
   fruits_data,
   fruits_target,
   random_state=42
)

# %% [markdown]
# ## 빈도수 확인

# %%
import collections

# %%
# fruits의 성적
collections.Counter(fruits['name'])
# Out:
# Counter({'apple': 35, 'berry': 14})
